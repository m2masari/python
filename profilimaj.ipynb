# %% [markdown]
# <a href="https://colab.research.google.com/github/m2masari/python/blob/master/profilimaj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gerekli paketleri yükleyelim önce. ComputerVision paketi (CV2) en önemlisi. İmajı okuma ve göstermek için kullanacağız. os directory, plt grafik, numpy de array için kullanılacak paketlerdir.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %% [markdown]
# Gdrive'a bağlanmmamız gerekiyor. Resmi gdrive'dan okuyacağız.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Gdrive'ında ki app klasörüne directory'yi yönlendirelim.

# %%
import os
os.chdir('/content/drive/My Drive/app/')

# %% [markdown]
# Klasördeki dosyaları listeleyelim

# %%
# !ls
# Out:
# Cat		    Dog		     profil_imaj.JPG	 Titanic.csv
# catversusdog.ipynb  grayimage.ipynb  pyspark.ipynb	 Titanic.csv.1
# deep		    kus		     rakamtahmini.ipynb

# %% [markdown]
# İmaj'ı okuyalım

# %%
image = cv2.imread('profil_imaj.JPG')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# İmajı gray formatına çevirelim

# %%
image = cv2.imread('profil_imaj.JPG',cv2.IMREAD_GRAYSCALE)
plt.imshow(image,cmap="gray")
plt.show()
